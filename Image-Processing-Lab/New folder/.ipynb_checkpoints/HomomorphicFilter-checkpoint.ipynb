# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "D:\\NC files\\MainDirectory\\imageLabAssignment\\Week 4\\prova.jpg"

I = cv2.imread(path, 0)
I = np.float32(I)
M, N = I.shape
I = I + 1
I_log = np.log(I)
I_fft = np.fft.fft2(I_log)
I_fft_shift = np.fft.fftshift(I_fft)
plt.imshow(np.log(np.abs(I_fft_shift)), "gray")
plt.show()

# %%
H = np.zeros(I.shape)
GL = 0.5
GH = 1.5
c = 1
D0 = 30
for u in range(M):
    for v in range(N):
        H[u, v] = (GH-GL)*(1-np.exp(-c*(np.sqrt((u-M/2)**2+(v-N/2)**2))/(D0**2)))+GL
plt.imshow(np.log(np.abs(H)), "gray")
plt.show()

# %%
I_FT2 = I_fft_shift*(H)
I_fft_i2 = np.fft.ifft2(I_FT2)
back2org2 = np.exp(np.abs(I_fft_i2))-1

# %%
fig = plt.figure(figsize=(20,20))
fig.add_subplot(1,2,1)
plt.imshow(I, "gray")
fig.add_subplot(1,2,2)
plt.imshow(back2org2, "gray")
plt.show()
